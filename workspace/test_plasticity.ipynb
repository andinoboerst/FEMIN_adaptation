# %%
from tct.tct_tractions import TCTExtractTractions

# %%
from shared.plotting import format_vectors_from_flat

# %%
import matplotlib.pyplot as plt

# %%
tct = TCTExtractTractions()
tct.run()
# Out:
# No Neumann BCs applied to this function space.
# No Neumann BCs applied to this function space.
# solving plasticity.................................] 0/6000
# { (c_0) : (v_0) } * dx(<Mesh #0>[everywhere], {})
# ...

# %%
tractions = format_vectors_from_flat(tct.data_out)

# %%
tractions
# Out:
# array([[[ 2.54829711e-03, -5.24587701e+01,  0.00000000e+00],
#         [ 2.71667292e-04, -6.60509622e+01,  0.00000000e+00],
#         [-7.50555704e-04, -7.26665403e+01,  0.00000000e+00],
#         ...,
#         [ 2.06805027e-04, -7.26658126e+01,  0.00000000e+00],
#         [ 4.18080942e-04, -6.60518726e+01,  0.00000000e+00],
#         [ 6.87246677e-05, -5.24586218e+01,  0.00000000e+00]],
#
#        [[ 5.09656906e-03, -1.04917023e+02,  0.00000000e+00],
#         [ 5.43331902e-04, -1.32101273e+02,  0.00000000e+00],
#         [-1.50110400e-03, -1.45332363e+02,  0.00000000e+00],
#         ...,
#         [ 4.13608014e-04, -1.45330908e+02,  0.00000000e+00],
#         [ 8.36157757e-04, -1.32103093e+02,  0.00000000e+00],
#         [ 1.37448657e-04, -1.04916726e+02,  0.00000000e+00]],
#
#        [[ 7.64479072e-03, -1.57374239e+02,  0.00000000e+00],
#         [ 8.14991150e-04, -1.98150279e+02,  0.00000000e+00],
#         [-2.25163748e-03, -2.17996752e+02,  0.00000000e+00],
#         ...,
# ...

# %%
tct.postprocess("u", "u", "norm", "test5")
# Out:
# error: XDG_RUNTIME_DIR is invalid or not set in the environment.
# MESA: error: ZINK: failed to choose pdev
# glx: failed to create drisw screen

# %%
plt.plot(tractions[:, 10, 1])
plt.show()
